# %% [markdown]
# <a href="https://colab.research.google.com/github/kirubaharan12/Apple-Analysis/blob/main/5_0_Updating_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0.DEFINING DATA

# %%
people = {
    "first": ["Corey", 'Jane', 'John'],
    "last": ["Schafer", 'Doe', 'Doe'],
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [markdown]
# # 1.CHANGE THE COLUMNS NAME IN DF

# %% [markdown]
# ## 1.1.CHANGING THE COLUMNS NAME USING LIST

# %%
df.columns = ['first_name', 'last_name', 'email']

# %%
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %% [markdown]
# ## 1.2.CHANGE THE COLUMNS NAME USING DICT
# **rename()**
# BY USING THE RENAME FUNCTION WE CAN CHANGE THE COLUMNS NAME USING DICT BY
#
# ->OLN NAME--KEY
#
# ->NEW NAME--VALUE

# %%
df.rename(columns={'first_name': 'first', 'last_name': 'last'}, inplace=True)

# %%
df.loc[2] = ['John', 'Smith', 'JohnSmith@email.com']

# %%
df.loc[2, ['last', 'email']] = ['Doe', 'JohnDoe@email.com']

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2, 'last'] = 'Smith'

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
df.at[2, 'last'] = 'Doe'

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
filt = (df['email'] == 'JohnDoe@email.com')
df[filt]['last'] = 'Smith'
# Out:
# <ipython-input-18-3767d2a961d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[filt]['last'] = 'Smith'

# %%
filt = (df['email'] == 'JohnDoe@email.com')
df.loc[filt, 'last'] = 'Smith'

# %%
df['email'] = df['email'].str.lower()

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %% [markdown]
# # 2.APPLY FUNCTION
#
# ---
#
# > Pandas.apply allow the users to pass a function and apply it on every single value of the Pandas series.
#
# **Parameter**
# *   fuunction->df.apply(np.sqrt)
# *   `axis=1` ti wil apply the function in row wise
#
#         >>> df.apply(np.sum, axis=1)
#         0    13
#         1    13
#         2    13
#         dtype: int64
#
#         Returning a list-like will result in a Series
# *   `axis=0`it will apply the funtion series wise.
#
#
#     >>> df.apply(np.sum, axis=0)
#     A    12
#     B    27
#     dtype: int64
#
#
# * result_type : {'expand', 'reduce', 'broadcast', None}, default None
# These only act when ``axis=1`` (columns):
#
# * **'expand'** : list-like results will be turned into columns.
# * **'reduce'** : returns a Series if possible rather than expanding
# list-like results. This is the opposite of 'expand'.
# * **'broadcast'** : results will be broadcast to the original shape of the DataFrame, the original index and columns will be retained.The default behaviour (None) depends on the return value of the applied function: list-like results will be returned as a Series of those. However if the apply function returns a Series these are expanded to columns.

# %% [markdown]
#         >>> df = pd.DataFrame([[4, 9]] * 3, columns=['A', 'B'])
#         >>> df
#            A  B
#         0  4  9
#         1  4  9
#         2  4  9
#
#         Using a numpy universal function (in this case the same as
#         ``np.sqrt(df)``):
#
#         >>> df.apply(np.sqrt)
#              A    B
#         0  2.0  3.0
#         1  2.0  3.0
#         2  2.0  3.0
#
#         Using a reducing function on either axis
#
#         >>> df.apply(np.sum, axis=0)
#         A    12
#         B    27
#         dtype: int64
#
#         >>> df.apply(np.sum, axis=1)
#         0    13
#         1    13
#         2    13
#         dtype: int64
#
#         Returning a list-like will result in a Series
#
#         >>> df.apply(lambda x: [1, 2], axis=1)
#         0    [1, 2]
#         1    [1, 2]
#         2    [1, 2]
#         dtype: object
#
#         Passing ``result_type='expand'`` will expand list-like results
#         to columns of a Dataframe
#
#         >>> df.apply(lambda x: [1, 2], axis=1, result_type='expand')
#            0  1
#         0  1  2
#         1  1  2
#         2  1  2
#
#         Returning a Series inside the function is similar to passing
#         ``result_type='expand'``. The resulting column names
#         will be the Series index.
#
#         >>> df.apply(lambda x: pd.Series([1, 2], index=['foo', 'bar']), axis=1)
#            foo  bar
#         0    1    2
#         1    1    2
#         2    1    2
#
#         Passing ``result_type='broadcast'`` will ensure the same shape
#         result, whether list-like or scalar is returned by the function,
#         and broadcast it along the axis. The resulting column names will
#         be the originals.
#
#         >>> df.apply(lambda x: [1, 2], axis=1, result_type='broadcast')
#            A  B
#         0  1  2
#         1  1  2
#         2  1  2

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
df['email'] = df['email'].apply(update_email)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM
# 1   Jane      Doe        JANEDOE@EMAIL.COM
# 2   John    Smith        JOHNDOE@EMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.lower())

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %%
df.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df.apply(lambda x: x.min())
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %% [markdown]
# #  3.applymap

# %%
df.applymap(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     5     17

# %%
df.applymap(str.lower)
# Out:
#    first     last                    email
# 0  corey  schafer  coreymschafer@gmail.com
# 1   jane      doe        janedoe@email.com
# 2   john    smith        johndoe@email.com

# %%
df['first'].map({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df['first'] = df['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})

# %%
df
# Out:
#    first     last                    email
# 0  Chris  Schafer  coreymschafer@gmail.com
# 1   Mary      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com
