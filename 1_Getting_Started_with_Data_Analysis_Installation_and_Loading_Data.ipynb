# %% [markdown]
# <a href="https://colab.research.google.com/github/kirubaharan12/Apple-Analysis/blob/main/1_Getting_Started_with_Data_Analysis_Installation_and_Loading_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/survey_results_public.csv')

# %%
df.tail(10)
#gives the last 10 columns in that data
# Out:
#       Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 3078        3092     I code primarily as a hobby      Yes   NaN         11
# 3079        3093  I am a developer by profession      Yes  45.0         12
# 3080        3094  I am a developer by profession      Yes  28.0         16
# 3081        3095  I am a developer by profession       No  25.0         16
# 3082        3096  I am a developer by profession      Yes  36.0         10
# 3083        3097     I code primarily as a hobby      Yes  18.0         11
# 3084        3098  I am a developer by profession      Yes  21.0         15
# 3085        3099  I am a developer by profession      Yes  26.0         19
# 3086        3100  I am a developer by profession      Yes  31.0         21
# 3087        3101  I am a developer by profession      Yes  19.0         11
#
#      CompFreq  CompTotal  ConvertedComp        Country          CurrencyDesc  \
# ...

# %%
df.shape
#gives the number of rows and columns
# Out:
# (3088, 61)

# %%
df.info()
#gives the informatyion about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3088 entries, 0 to 3087
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    3088 non-null   int64
#  1   MainBranch                    3088 non-null   object
#  2   Hobbyist                      3088 non-null   object
#  3   Age                           2709 non-null   float64
#  4   Age1stCode                    3065 non-null   object
#  5   CompFreq                      2294 non-null   object
#  6   CompTotal                     2138 non-null   float64
#  7   ConvertedComp                 2131 non-null   float64
#  8   Country                       3088 non-null   object
#  9   CurrencyDesc                  2563 non-null   object
#  10  CurrencySymbol                2563 non-null   object
#  11  DatabaseDesireNextYear        2331 non-null   object
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
"""The code `pd.set_option('display.max_columns', 85)` and `pd.set_option('display.max_rows', 85)` are used to configure the pandas library to display a maximum of 85 columns and 85 rows of a DataFrame when it is printed.
By default, pandas only displays the first 20 columns and the first 60 rows of a DataFrame. This can be limiting when working with larger datasets.
"""
# Out:
# "The code `pd.set_option('display.max_columns', 85)` and `pd.set_option('display.max_rows', 85)` are used to configure the pandas library to display a maximum of 85 columns and 85 rows of a DataFrame when it is printed.\nBy default, pandas only displays the first 20 columns and the first 60 rows of a DataFrame. This can be limiting when working with larger datasets.\n"

# %%
schema_df = pd.read_csv('/content/survey_results_public.csv')

# %%
schema_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 15198       15249             I am a student who is learning to code      Yes
# 15199       15250                     I am a developer by profession      Yes
# 15200       15251                     I am a developer by profession       No
# 15201       15252                     I am a developer by profession      Yes
# 15202       15253                     I am a developer by profession      Yes
#
# ...

# %%
pd
# Out:
# <module 'pandas' from '/Users/coreyschafer/tutorial_env/lib/python3.7/site-packages/pandas/__init__.py'>
